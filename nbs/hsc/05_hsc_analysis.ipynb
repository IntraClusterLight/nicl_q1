# %% [markdown]
# # HSC Analysis
#
# > This is a worked example of analysing the ICL in images from the HSC-SSP deep survey.

# %%
# | default_exp hsc.analysis

# %% [markdown]
# Here we execute the final analysis. The previous steps are defined and demonstrated in [HSC Preparation](01_hsc_preparation.ipynb), [HSC Masking](02_hsc_masking.ipynb), and [HSC Measurement](03_hsc_measurement.ipynb).
