# %%
#| hide
from nicl.main import *

# %% [markdown]
# # nicl
#
# > New Nottingham ICL code

# %% [markdown]
# This is an attempt to bring together ideas and code to do something good.

# %% [markdown]
# ## Install
#
# This software is absolutely not ready for use by anyone, but when it is, it will be installable using `pip`.

# %% [markdown]
# ```sh
# pip install nicl
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# To be figured out!
