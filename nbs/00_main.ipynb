# %% [markdown]
# # main
#
# > This is the main entry point for using this package to measure ICL in images of galaxy clusters.

# %%
#| default_exp main

# %%
#| export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %% [markdown]
# Now I'm going to demonstrate using this function.

# %%
say_hello("Steven")
# Out:
# 'Hello Steven!'

# %% [markdown]
# Let's test it...

# %%
from fastcore.test import *
test_eq(say_hello("Bamford"), "Hello Bamford!")

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()
