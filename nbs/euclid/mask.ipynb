# %% [markdown]
# # mask
#
# > Mask sources in a Euclid image.

# %%
# | default_exp euclid.mask

# %%
# | exporti

# %%
# | export

# %% [markdown]
# ## Example
#
# The following is an example of creating a mask for an image.

# %%
# | hide
import nbdev

nbdev.nbdev_export()
